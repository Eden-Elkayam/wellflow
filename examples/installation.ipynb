# %% [markdown]
# # Wellflow Trial

# %% [markdown]
# recreate a new environment with the appropriate python version

# %%
# %%bash
# conda create --name wellflow python=3.11 --yes
# Out:
# 2 channel Terms of Service accepted
# Retrieving notices: -
# Unexpected error writing token file:
#   path: /Users/edenelkayam/.conda/aau_token_host
#   exception: write() argument must be str, not None
# done
# Channels:
#  - defaults
#  - bioconda
#  - conda-forge
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/edenelkayam/miniconda3/envs/wellflow
#
#   added / updated specs:
#     - python=3.11
#
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/osx-arm64::bzip2-1.0.8-h80987f9_6
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-2025.12.2-hca03da5_0
#   expat              pkgs/main/osx-arm64::expat-2.7.3-h50f4ffc_4
#   libcxx             pkgs/main/osx-arm64::libcxx-20.1.8-hd7fd590_1
#   libexpat           pkgs/main/osx-arm64::libexpat-2.7.3-h50f4ffc_4
#   libffi             pkgs/main/osx-arm64::libffi-3.4.4-hca03da5_1
# ...

# %% [markdown]
# Manually set the kernel to the environment you want -- prefferably DONT run the following shell in this notebook, but directly in the terminal.

# %%
# %%bash
# conda activate wellflow

# %% [markdown]
# install wellflow

# %%
# %%bash
# pip install git+https://github.com/flamholz-lab/wellflow.git
# Out:
# ...
#   Cloning https://github.com/flamholz-lab/wellflow.git to /private/var/folders/44/prh85nn948x5dmsk9lztdp440000gn/T/pip-req-build-onwltqe2
#   Running command git clone --filter=blob:none --quiet https://github.com/flamholz-lab/wellflow.git /private/var/folders/44/prh85nn948x5dmsk9lztdp440000gn/T/pip-req-build-onwltqe2
#   Resolved https://github.com/flamholz-lab/wellflow.git to commit f7fff3e348a107e32900ddcb327f23a445f542d8
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (91 kB)
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...

# %%
import wellflow as wf
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import wellflow as wf
#
# File ~/miniconda3/envs/wellflow/lib/python3.11/site-packages/wellflow/__init__.py:1
# ----> 1 from .plate import (
#       2     read_plate_measurements,
#       3     read_plate_layout,
#       4     merge_measurements_and_conditions,
#       5     read_flagged_wells,
#       6     add_flag_column,
#       7     drop_flags,
#       8     drop_col,
#       9     drop_row,
#      10     drop_well,
#      11     with_blank_corrected_od,
#      12     with_smoothed_od,
#      13     add_growth_rate,
#      14     estimate_early_od_threshold,
#      15     summarize_mu_max,
#      16 )
#      18 # Backwards-compatible aliases for older API names
#      19 add_blank_value = with_blank_corrected_od
#
# File ~/miniconda3/envs/wellflow/lib/python3.11/site-packages/wellflow/plate.py:7
# ...
